# %%
import pandas as pd
import numpy as np

# %%
# Read the data file from Google Colab
data = pd.read_csv('data.csv')

# Print the data
data.head()
# Out:
#   Unnamed: 0         X1   X2         X3        X4   X5     X6     X7     X8  \
# 0         ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3
# 1          1      20000    2          2         1   24      2      2     -1
# 2          2     120000    2          2         2   26     -1      2      0
# 3          3      90000    2          2         2   34      0      0      0
# 4          4      50000    2          2         1   37      0      0      0
#
#       X9  ...        X15        X16        X17       X18       X19       X20  \
# 0  PAY_4  ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3
# 1     -1  ...          0          0          0         0       689         0
# 2      0  ...       3272       3455       3261         0      1000      1000
# 3      0  ...      14331      14948      15549      1518      1500      1000
# 4      0  ...      28314      28959      29547      2000      2019      1200
#
#         X21       X22       X23                           Y
# 0  PAY_AMT4  PAY_AMT5  PAY_AMT6  default payment next month
# 1         0         0         0                           1
# 2      1000         0      2000                           1
# 3      1000      1000      5000                           0
# 4      1100      1069      1000                           0
#
# [5 rows x 25 columns]

# %%
# prompt: eliminate first row to count,  because those are names, don't completely remove it

import pandas as pd
data = pd.read_csv('data.csv', skiprows=1)

# %%
data.tail()
# Out:
#           ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  \
# 29995  29996     220000    1          3         1   39      0      0      0
# 29996  29997     150000    1          3         2   43     -1     -1     -1
# 29997  29998      30000    1          2         2   37      4      3      2
# 29998  29999      80000    1          3         1   41      1     -1      0
# 29999  30000      50000    1          2         1   46      0      0      0
#
#        PAY_4  ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  \
# 29995      0  ...      88004      31237      15980      8500     20000
# 29996     -1  ...       8979       5190          0      1837      3526
# 29997     -1  ...      20878      20582      19357         0         0
# 29998      0  ...      52774      11855      48944     85900      3409
# 29999      0  ...      36535      32428      15313      2078      1800
#
#        PAY_AMT3  PAY_AMT4  PAY_AMT5  PAY_AMT6  default payment next month
# 29995      5003      3047      5000      1000                           0
# 29996      8998       129         0         0                           0
# 29997     22000      4200      2000      3100                           1
# 29998      1178      1926     52964      1804                           1
# 29999      1430      1000      1000      1000                           1
#
# [5 rows x 25 columns]

# %%
# Get descriptive statistics and round the values
pande = data.describe().round(2)

# Transpose the DataFrame and display it
pande_transposed = pande.transpose()
pande_transposed
# Out:
#                               count       mean        std       min       25%  \
# ID                          30000.0   15000.50    8660.40       1.0   7500.75
# LIMIT_BAL                   30000.0  167484.32  129747.66   10000.0  50000.00
# SEX                         30000.0       1.60       0.49       1.0      1.00
# EDUCATION                   30000.0       1.85       0.79       0.0      1.00
# MARRIAGE                    30000.0       1.55       0.52       0.0      1.00
# AGE                         30000.0      35.49       9.22      21.0     28.00
# PAY_0                       30000.0      -0.02       1.12      -2.0     -1.00
# PAY_2                       30000.0      -0.13       1.20      -2.0     -1.00
# PAY_3                       30000.0      -0.17       1.20      -2.0     -1.00
# PAY_4                       30000.0      -0.22       1.17      -2.0     -1.00
# PAY_5                       30000.0      -0.27       1.13      -2.0     -1.00
# PAY_6                       30000.0      -0.29       1.15      -2.0     -1.00
# BILL_AMT1                   30000.0   51223.33   73635.86 -165580.0   3558.75
# BILL_AMT2                   30000.0   49179.08   71173.77  -69777.0   2984.75
# BILL_AMT3                   30000.0   47013.15   69349.39 -157264.0   2666.25
# BILL_AMT4                   30000.0   43262.95   64332.86 -170000.0   2326.75
# BILL_AMT5                   30000.0   40311.40   60797.16  -81334.0   1763.00
# BILL_AMT6                   30000.0   38871.76   59554.11 -339603.0   1256.00
# PAY_AMT1                    30000.0    5663.58   16563.28       0.0   1000.00
# PAY_AMT2                    30000.0    5921.16   23040.87       0.0    833.00
# PAY_AMT3                    30000.0    5225.68   17606.96       0.0    390.00
# PAY_AMT4                    30000.0    4826.08   15666.16       0.0    296.00
# PAY_AMT5                    30000.0    4799.39   15278.31       0.0    252.50
# PAY_AMT6                    30000.0    5215.50   17777.47       0.0    117.75
# default payment next month  30000.0       0.22       0.42       0.0      0.00
#
#                                  50%        75%        max
# ID                           15000.5   22500.25    30000.0
# LIMIT_BAL                   140000.0  240000.00  1000000.0
# SEX                              2.0       2.00        2.0
# EDUCATION                        2.0       2.00        6.0
# MARRIAGE                         2.0       2.00        3.0
# AGE                             34.0      41.00       79.0
# PAY_0                            0.0       0.00        8.0
# PAY_2                            0.0       0.00        8.0
# PAY_3                            0.0       0.00        8.0
# PAY_4                            0.0       0.00        8.0
# PAY_5                            0.0       0.00        8.0
# PAY_6                            0.0       0.00        8.0
# BILL_AMT1                    22381.5   67091.00   964511.0
# BILL_AMT2                    21200.0   64006.25   983931.0
# BILL_AMT3                    20088.5   60164.75  1664089.0
# BILL_AMT4                    19052.0   54506.00   891586.0
# BILL_AMT5                    18104.5   50190.50   927171.0
# BILL_AMT6                    17071.0   49198.25   961664.0
# PAY_AMT1                      2100.0    5006.00   873552.0
# PAY_AMT2                      2009.0    5000.00  1684259.0
# PAY_AMT3                      1800.0    4505.00   896040.0
# PAY_AMT4                      1500.0    4013.25   621000.0
# PAY_AMT5                      1500.0    4031.50   426529.0
# PAY_AMT6                      1500.0    4000.00   528666.0
# default payment next month       0.0       0.00        1.0

# %%
data.info()

#To check the non null values count
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 25 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   ID                          30000 non-null  int64
#  1   LIMIT_BAL                   30000 non-null  int64
#  2   SEX                         30000 non-null  int64
#  3   EDUCATION                   30000 non-null  int64
#  4   MARRIAGE                    30000 non-null  int64
#  5   AGE                         30000 non-null  int64
#  6   PAY_0                       30000 non-null  int64
#  7   PAY_2                       30000 non-null  int64
#  8   PAY_3                       30000 non-null  int64
#  9   PAY_4                       30000 non-null  int64
#  10  PAY_5                       30000 non-null  int64
#  11  PAY_6                       30000 non-null  int64
#  12  BILL_AMT1                   30000 non-null  int64
#  13  BILL_AMT2                   30000 non-null  int64
#  14  BILL_AMT3                   30000 non-null  int64
#  15  BILL_AMT4                   30000 non-null  int64
#  16  BILL_AMT5                   30000 non-null  int64
#  17  BILL_AMT6                   30000 non-null  int64
#  18  PAY_AMT1                    30000 non-null  int64
#  19  PAY_AMT2                    30000 non-null  int64
#  20  PAY_AMT3                    30000 non-null  int64
#  21  PAY_AMT4                    30000 non-null  int64
#  22  PAY_AMT5                    30000 non-null  int64
#  23  PAY_AMT6                    30000 non-null  int64
#  24  default payment next month  30000 non-null  int64
# dtypes: int64(25)
# memory usage: 5.7 MB

# %%
data.isnull().sum()

#To show all null variables in each variable
#if null values are available, to remove null rows
#data.dropna()
#data.fillna(data.mean()) to fill null values with mean
# Out:
# ID                            0
# LIMIT_BAL                     0
# SEX                           0
# EDUCATION                     0
# MARRIAGE                      0
# AGE                           0
# PAY_0                         0
# PAY_2                         0
# PAY_3                         0
# PAY_4                         0
# PAY_5                         0
# PAY_6                         0
# BILL_AMT1                     0
# BILL_AMT2                     0
# BILL_AMT3                     0
# BILL_AMT4                     0
# BILL_AMT5                     0
# BILL_AMT6                     0
# PAY_AMT1                      0
# PAY_AMT2                      0
# PAY_AMT3                      0
# PAY_AMT4                      0
# PAY_AMT5                      0
# PAY_AMT6                      0
# default payment next month    0
# dtype: int64

# %%
data.duplicated().sum()
#if duplicates found, data.drop_duplicates()
# Out:
# 0

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import matplotlib.pyplot as plt
import seaborn as sns


# Display boxplots for each column
for column in data.columns:
    plt.figure(figsize=(5, 3))
    sns.boxplot(y=data[column])
    plt.title(f'Boxplot of {column}')
    plt.ylabel(column)
    plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Count plot for the SEX column
plt.figure(figsize=(5, 3))
sns.countplot(x='SEX', data=data)
plt.title('Distribution of SEX')
plt.xlabel('SEX')
plt.ylabel('Count')
plt.xticks(ticks=[0, 1], labels=['Male', 'Female'])
plt.show()

# %%
# Assuming 'Education' is the column name in your dataset
education_counts = data['EDUCATION'].value_counts().sort_index()

plt.figure(figsize=(8, 6))
education_counts.plot(kind='bar', color='skyblue')
plt.title('Distribution of Education Levels')
plt.xlabel('Education Level')
plt.ylabel('Count')
plt.xticks(rotation=0)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
data = data[~data['EDUCATION'].isin([0, 5, 6])]


print("Number of rows after cleaning education column:", len(data))
print("Number of columns:", len(data.columns))
# Out:
# Number of rows after cleaning education column: 29655
# Number of columns: 25

# %%
data = data[data['MARRIAGE'] != 0]

# %%
import pandas as pd

# Assuming 'df' is your DataFrame
print("Number of rows after cleaning marriage column:", len(data))
print("Number of columns:", len(data.columns))
# Out:
# Number of rows after cleaning marriage column: 29601
# Number of columns: 25

# %%
columns_to_check = ['PAY_0', 'PAY_2', 'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6']

for column in columns_to_check:
    data = data[data[column] != -2]

# %%
import pandas as pd

# Assuming 'df' is your DataFrame
print("Number of rows after cleaning PAY columns:", len(data))
print("Number of columns:", len(data.columns))
# Out:
# Number of rows after cleaning PAY columns: 23150
# Number of columns: 25

# %%
columns_to_check = ['BILL_AMT1', 'BILL_AMT2', 'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6']

for column in columns_to_check:
    data = data[data[column] >= 0]

# %%
import pandas as pd

# Assuming 'df' is your DataFrame
print("Number of rows after cleaning BILL_AMT columns:", len(data))
print("Number of columns:", len(data.columns))
# Out:
# Number of rows after cleaning BILL_AMT columns: 22455
# Number of columns: 25

# %%
# Get descriptive statistics and round the values
pande = data.describe().round(2)

# Transpose the DataFrame and display it
pande_transposed = pande.transpose()
pande_transposed
# Out:
#                               count       mean        std      min      25%  \
# ID                          22455.0   14927.87    8608.85      2.0   7507.0
# LIMIT_BAL                   22455.0  155047.15  127046.88  10000.0  50000.0
# SEX                         22455.0       1.59       0.49      1.0      1.0
# EDUCATION                   22455.0       1.86       0.70      1.0      1.0
# MARRIAGE                    22455.0       1.56       0.52      1.0      1.0
# AGE                         22455.0      35.24       9.31     21.0     28.0
# PAY_0                       22455.0       0.19       0.99     -1.0      0.0
# PAY_2                       22455.0       0.21       1.03     -1.0      0.0
# PAY_3                       22455.0       0.19       1.02     -1.0      0.0
# PAY_4                       22455.0       0.15       0.99     -1.0      0.0
# PAY_5                       22455.0       0.11       0.94     -1.0      0.0
# PAY_6                       22455.0       0.11       0.95     -1.0      0.0
# BILL_AMT1                   22455.0   62461.62   77810.57      0.0  10670.0
# BILL_AMT2                   22455.0   60798.56   75460.09      0.0  11035.0
# BILL_AMT3                   22455.0   58414.42   72605.88      0.0  11283.0
# BILL_AMT4                   22455.0   54355.38   68422.64      0.0  10728.0
# BILL_AMT5                   22455.0   50802.20   64685.38      0.0   9803.0
# BILL_AMT6                   22455.0   48972.61   63421.68      0.0   8644.5
# PAY_AMT1                    22455.0    5995.86   16477.75      0.0   1440.0
# PAY_AMT2                    22455.0    6002.38   19820.42      0.0   1371.0
# PAY_AMT3                    22455.0    5473.47   17819.70      0.0   1000.0
# PAY_AMT4                    22455.0    4972.84   14743.13      0.0    780.0
# PAY_AMT5                    22455.0    4986.96   14581.45      0.0    756.0
# PAY_AMT6                    22455.0    5209.15   16892.21      0.0    649.0
# default payment next month  22455.0       0.23       0.42      0.0      0.0
#
#                                  50%       75%        max
# ID                           14941.0   22218.5    30000.0
# LIMIT_BAL                   120000.0  220000.0  1000000.0
# SEX                              2.0       2.0        2.0
# EDUCATION                        2.0       2.0        4.0
# MARRIAGE                         2.0       2.0        3.0
# AGE                             34.0      41.0       79.0
# PAY_0                            0.0       0.0        8.0
# PAY_2                            0.0       0.0        8.0
# PAY_3                            0.0       0.0        8.0
# PAY_4                            0.0       0.0        8.0
# PAY_5                            0.0       0.0        8.0
# PAY_6                            0.0       0.0        8.0
# BILL_AMT1                    35417.0   82575.0   964511.0
# BILL_AMT2                    34439.0   80332.0   983931.0
# BILL_AMT3                    31499.0   77033.5   693131.0
# BILL_AMT4                    28894.0   71562.5   891586.0
# BILL_AMT5                    27268.0   66854.5   927171.0
# BILL_AMT6                    26036.0   64473.0   961664.0
# PAY_AMT1                      2602.0    5500.0   873552.0
# PAY_AMT2                      2500.0    5200.0  1227082.0
# PAY_AMT3                      2000.0    5000.0   896040.0
# PAY_AMT4                      2000.0    4732.5   621000.0
# PAY_AMT5                      2000.0    4690.5   426529.0
# PAY_AMT6                      2000.0    4500.0   528666.0
# default payment next month       0.0       0.0        1.0

# %%
# Assuming 'Education' is the column name in your dataset
education_counts = data['EDUCATION'].value_counts().sort_index()

plt.figure(figsize=(8, 6))
education_counts.plot(kind='bar', color='skyblue')
plt.title('Distribution of Education Levels')
plt.xlabel('Education Level')
plt.ylabel('Count')
plt.xticks(rotation=0)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
for column in data.columns:
    plt.figure(figsize=(5, 3))
    sns.boxplot(y=data[column])
    plt.title(f'Boxplot of {column}')
    plt.ylabel(column)
    plt.show()
